# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
# Only consider the top 20k words
max_features  = 20000  
embedding_dim = 128
maxlen = 500

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=max_features)
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_val = keras.preprocessing.sequence.pad_sequences(x_val, maxlen=maxlen)
# Out:
# 25000 Training sequences
# 25000 Validation sequences

# %%
# Input for variable-length sequences of integers
inputs = keras.Input(shape=(maxlen,), dtype="int32")

# Embed each integer in a 128-dimensional vector
x = layers.Embedding(max_features, 128)(inputs)

# Add 2 LSTMs
x = layers.LSTM(64, return_sequences=True)(x)
x = layers.LSTM(64)(x)

# Add a classifier
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500)]             0
#
#  embedding (Embedding)       (None, 500, 128)          2560000
#
#  lstm (LSTM)                 (None, 500, 64)           49408
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 2,642,497
# Trainable params: 2,642,497
# Non-trainable params: 0
# _________________________________________________________________
# 2022-12-21 10:44:26.121475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.139572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.139661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.139918: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-21 10:44:26.140447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.140511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.140552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.405354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.405450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.405500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 10:44:26.405555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45924 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 2022-12-21 10:44:28.481945: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-21 10:44:28.620439: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 49/49 [==============================] - 5s 73ms/step - loss: 0.5052 - accuracy: 0.7342 - val_loss: 0.3230 - val_accuracy: 0.8641
# Epoch 2/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.2145 - accuracy: 0.9198 - val_loss: 0.3216 - val_accuracy: 0.8745
# Epoch 3/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.1249 - accuracy: 0.9580 - val_loss: 0.3678 - val_accuracy: 0.8652
# Epoch 4/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.0948 - accuracy: 0.9692 - val_loss: 0.4097 - val_accuracy: 0.8616
# Epoch 5/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0677 - accuracy: 0.9793 - val_loss: 0.4501 - val_accuracy: 0.8543
# Epoch 6/50
# 49/49 [==============================] - 3s 64ms/step - loss: 0.0522 - accuracy: 0.9842 - val_loss: 0.5584 - val_accuracy: 0.8524
# Epoch 7/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0295 - accuracy: 0.9922 - val_loss: 0.6493 - val_accuracy: 0.8498
# Epoch 8/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.5792 - val_accuracy: 0.8504
# Epoch 9/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0315 - accuracy: 0.9906 - val_loss: 0.6732 - val_accuracy: 0.8470
# Epoch 10/50
# 49/49 [==============================] - 3s 63ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.7695 - val_accuracy: 0.8456
# Epoch 11/50
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0365 - accuracy: 0.9886 - val_loss: 0.5976 - val_accuracy: 0.8430
# Epoch 12/50
# 49/49 [==============================] - 3s 66ms/step - loss: 0.0336 - accuracy: 0.9899 - val_loss: 0.6561 - val_accuracy: 0.8446
# Epoch 13/50
# 49/49 [==============================] - 3s 66ms/step - loss: 0.0154 - accuracy: 0.9960 - val_loss: 0.7433 - val_accuracy: 0.8502
# Epoch 14/50
# 49/49 [==============================] - 3s 67ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 0.8144 - val_accuracy: 0.8462
# Epoch 15/50
# 49/49 [==============================] - 3s 66ms/step - loss: 0.0057 - accuracy: 0.9992 - val_loss: 0.8813 - val_accuracy: 0.8469
# Epoch 16/50
# 49/49 [==============================] - 3s 64ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.8297 - val_accuracy: 0.8452
# Epoch 17/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.9329 - val_accuracy: 0.8297
# Epoch 18/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.8043 - val_accuracy: 0.8443
# Epoch 19/50
# 49/49 [==============================] - 3s 67ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.8588 - val_accuracy: 0.8478
# Epoch 20/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.9105 - val_accuracy: 0.8454
# Epoch 21/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.8668 - val_accuracy: 0.8416
# Epoch 22/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.9651 - val_accuracy: 0.8457
# Epoch 23/50
# 49/49 [==============================] - 3s 63ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.9086 - val_accuracy: 0.8460
# Epoch 24/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.8042 - val_accuracy: 0.8492
# Epoch 25/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.8992 - val_accuracy: 0.8440
# Epoch 26/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.7887 - val_accuracy: 0.8508
# Epoch 27/50
# 49/49 [==============================] - 3s 59ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.9236 - val_accuracy: 0.8438
# Epoch 28/50
# 49/49 [==============================] - 3s 66ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.8023 - val_accuracy: 0.8484
# Epoch 29/50
# 49/49 [==============================] - 3s 62ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.9303 - val_accuracy: 0.8471
# Epoch 30/50
# 49/49 [==============================] - 3s 61ms/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.6921 - val_accuracy: 0.8192
# Epoch 31/50
# 49/49 [==============================] - 3s 63ms/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 0.8245 - val_accuracy: 0.8485
# Epoch 32/50
# 49/49 [==============================] - 3s 60ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.8158 - val_accuracy: 0.8471
# Epoch 33/50
# 49/49 [==============================] - 3s 58ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.8936 - val_accuracy: 0.8467
# Epoch 34/50
# 49/49 [==============================] - 3s 58ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 1.0353 - val_accuracy: 0.8464
# Epoch 35/50
# 49/49 [==============================] - 3s 66ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.9914 - val_accuracy: 0.8458
# Epoch 36/50
# 49/49 [==============================] - 3s 59ms/step - loss: 8.3621e-04 - accuracy: 0.9999 - val_loss: 1.0534 - val_accuracy: 0.8462
# Epoch 37/50
# 49/49 [==============================] - 3s 59ms/step - loss: 6.4829e-04 - accuracy: 0.9999 - val_loss: 1.0503 - val_accuracy: 0.8469
# Epoch 38/50
# 49/49 [==============================] - 3s 63ms/step - loss: 5.1627e-04 - accuracy: 1.0000 - val_loss: 1.1102 - val_accuracy: 0.8455
# Epoch 39/50
# 49/49 [==============================] - 3s 61ms/step - loss: 4.6944e-04 - accuracy: 1.0000 - val_loss: 1.1336 - val_accuracy: 0.8452
# Epoch 40/50
# 49/49 [==============================] - 3s 61ms/step - loss: 4.5571e-04 - accuracy: 1.0000 - val_loss: 1.1506 - val_accuracy: 0.8450
# Epoch 41/50
# 49/49 [==============================] - 3s 65ms/step - loss: 4.4471e-04 - accuracy: 1.0000 - val_loss: 1.1695 - val_accuracy: 0.8451
# Epoch 42/50
# 49/49 [==============================] - 3s 63ms/step - loss: 4.3631e-04 - accuracy: 1.0000 - val_loss: 1.1858 - val_accuracy: 0.8450
# Epoch 43/50
# 49/49 [==============================] - 3s 64ms/step - loss: 4.2761e-04 - accuracy: 1.0000 - val_loss: 1.1996 - val_accuracy: 0.8451
# Epoch 44/50
# 49/49 [==============================] - 3s 61ms/step - loss: 4.2073e-04 - accuracy: 1.0000 - val_loss: 1.2137 - val_accuracy: 0.8452
# Epoch 45/50
# 49/49 [==============================] - 3s 63ms/step - loss: 4.1391e-04 - accuracy: 1.0000 - val_loss: 1.2263 - val_accuracy: 0.8449
# Epoch 46/50
# 49/49 [==============================] - 3s 59ms/step - loss: 4.0844e-04 - accuracy: 1.0000 - val_loss: 1.2396 - val_accuracy: 0.8449
# Epoch 47/50
# 49/49 [==============================] - 3s 61ms/step - loss: 4.0278e-04 - accuracy: 1.0000 - val_loss: 1.2538 - val_accuracy: 0.8445
# Epoch 48/50
# 49/49 [==============================] - 3s 62ms/step - loss: 3.9593e-04 - accuracy: 1.0000 - val_loss: 1.2618 - val_accuracy: 0.8445
# Epoch 49/50
# 49/49 [==============================] - 3s 64ms/step - loss: 3.9017e-04 - accuracy: 1.0000 - val_loss: 1.2732 - val_accuracy: 0.8439
# Epoch 50/50
# 49/49 [==============================] - 3s 58ms/step - loss: 3.8505e-04 - accuracy: 1.0000 - val_loss: 1.2868 - val_accuracy: 0.8434

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

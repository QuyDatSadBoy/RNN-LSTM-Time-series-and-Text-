# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
# Only consider the top 20k words
max_features  = 20000  
embedding_dim = 128
maxlen = 500

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=max_features)
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_val = keras.preprocessing.sequence.pad_sequences(x_val, maxlen=maxlen)
# Out:
# 25000 Training sequences
# 25000 Validation sequences

# %%
# model
inputs = tf.keras.Input(shape=(maxlen,),  dtype="int64")
x = layers.Embedding(max_features, embedding_dim)(inputs)

x = layers.Conv1D(128, 7, 
                  padding="valid", 
                  activation="relu", 
                  strides=3)(x)
x = layers.Conv1D(256, 7, 
                  padding="valid", 
                  activation="relu", 
                  strides=3)(x)

# Flatten and Dense
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dense(1, activation="sigmoid")(x)

model = tf.keras.Model(inputs, x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500)]             0
#
#  embedding (Embedding)       (None, 500, 128)          2560000
#
#  conv1d (Conv1D)             (None, 165, 128)          114816
#
#  conv1d_1 (Conv1D)           (None, 53, 256)           229632
#
#  flatten (Flatten)           (None, 13568)             0
#
#  dense (Dense)               (None, 128)               1736832
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,641,409
# Trainable params: 4,641,409
# Non-trainable params: 0
# _________________________________________________________________
# 2022-12-21 09:41:24.265240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.286120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.286191: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.286508: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-21 09:41:24.287845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.287936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.287976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.543354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.543443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.543492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-21 09:41:24.543544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46136 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 2022-12-21 09:41:25.805535: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
#  18/782 [..............................] - ETA: 2s - loss: 0.7017 - accuracy: 0.4757
# 2022-12-21 09:41:26.554853: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 782/782 [==============================] - 10s 10ms/step - loss: 0.5039 - accuracy: 0.6915 - val_loss: 0.2947 - val_accuracy: 0.8748
# Epoch 2/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.1834 - accuracy: 0.9304 - val_loss: 0.3056 - val_accuracy: 0.8723
# Epoch 3/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0532 - accuracy: 0.9820 - val_loss: 0.5114 - val_accuracy: 0.8539
# Epoch 4/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 0.7711 - val_accuracy: 0.8496
# Epoch 5/50
# 782/782 [==============================] - 8s 11ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.8951 - val_accuracy: 0.8506
# Epoch 6/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.9007 - val_accuracy: 0.8528
# Epoch 7/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.9728 - val_accuracy: 0.8429
# Epoch 8/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 1.1570 - val_accuracy: 0.8274
# Epoch 9/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 1.2729 - val_accuracy: 0.8386
# Epoch 10/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 1.3077 - val_accuracy: 0.8441
# Epoch 11/50
# 782/782 [==============================] - 6s 8ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 1.1894 - val_accuracy: 0.8464
# Epoch 12/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 1.1708 - val_accuracy: 0.8434
# Epoch 13/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 1.1885 - val_accuracy: 0.8461
# Epoch 14/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 1.5891 - val_accuracy: 0.8445
# Epoch 15/50
# 782/782 [==============================] - 6s 8ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 1.1468 - val_accuracy: 0.8448
# Epoch 16/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 1.2656 - val_accuracy: 0.8485
# Epoch 17/50
# 782/782 [==============================] - 8s 10ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.9612 - val_accuracy: 0.8450
# Epoch 18/50
# 782/782 [==============================] - 8s 11ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 1.7844 - val_accuracy: 0.8215
# Epoch 19/50
# 782/782 [==============================] - 8s 11ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 1.1726 - val_accuracy: 0.8426
# Epoch 20/50
# 782/782 [==============================] - 8s 11ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.5239 - val_accuracy: 0.8468
# Epoch 21/50
# 782/782 [==============================] - 8s 11ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 1.7385 - val_accuracy: 0.8451
# Epoch 22/50
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2683e-04 - accuracy: 1.0000 - val_loss: 2.0865 - val_accuracy: 0.8471
# Epoch 23/50
# 782/782 [==============================] - 9s 11ms/step - loss: 6.2551e-06 - accuracy: 1.0000 - val_loss: 2.2624 - val_accuracy: 0.8443
# Epoch 24/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.3865e-06 - accuracy: 1.0000 - val_loss: 2.2754 - val_accuracy: 0.8456
# Epoch 25/50
# 782/782 [==============================] - 8s 10ms/step - loss: 5.2257e-07 - accuracy: 1.0000 - val_loss: 2.3063 - val_accuracy: 0.8455
# Epoch 26/50
# 782/782 [==============================] - 7s 10ms/step - loss: 3.5430e-07 - accuracy: 1.0000 - val_loss: 2.3405 - val_accuracy: 0.8458
# Epoch 27/50
# 782/782 [==============================] - 9s 11ms/step - loss: 2.3480e-07 - accuracy: 1.0000 - val_loss: 2.3811 - val_accuracy: 0.8460
# Epoch 28/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.5155e-07 - accuracy: 1.0000 - val_loss: 2.4336 - val_accuracy: 0.8456
# Epoch 29/50
# 782/782 [==============================] - 8s 11ms/step - loss: 9.7137e-08 - accuracy: 1.0000 - val_loss: 2.4845 - val_accuracy: 0.8459
# Epoch 30/50
# 782/782 [==============================] - 8s 11ms/step - loss: 6.1877e-08 - accuracy: 1.0000 - val_loss: 2.5455 - val_accuracy: 0.8460
# Epoch 31/50
# 782/782 [==============================] - 8s 11ms/step - loss: 4.0273e-08 - accuracy: 1.0000 - val_loss: 2.5919 - val_accuracy: 0.8458
# Epoch 32/50
# 782/782 [==============================] - 8s 10ms/step - loss: 2.6765e-08 - accuracy: 1.0000 - val_loss: 2.6511 - val_accuracy: 0.8462
# Epoch 33/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.7949e-08 - accuracy: 1.0000 - val_loss: 2.7002 - val_accuracy: 0.8462
# Epoch 34/50
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2021e-08 - accuracy: 1.0000 - val_loss: 2.7586 - val_accuracy: 0.8461
# Epoch 35/50
# 782/782 [==============================] - 8s 11ms/step - loss: 8.1488e-09 - accuracy: 1.0000 - val_loss: 2.8156 - val_accuracy: 0.8460
# Epoch 36/50
# 782/782 [==============================] - 8s 10ms/step - loss: 5.5838e-09 - accuracy: 1.0000 - val_loss: 2.8637 - val_accuracy: 0.8460
# Epoch 37/50
# 782/782 [==============================] - 8s 11ms/step - loss: 3.8829e-09 - accuracy: 1.0000 - val_loss: 2.9173 - val_accuracy: 0.8462
# Epoch 38/50
# 782/782 [==============================] - 8s 11ms/step - loss: 2.7161e-09 - accuracy: 1.0000 - val_loss: 2.9644 - val_accuracy: 0.8463
# Epoch 39/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.9426e-09 - accuracy: 1.0000 - val_loss: 3.0113 - val_accuracy: 0.8463
# Epoch 40/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.4248e-09 - accuracy: 1.0000 - val_loss: 3.0575 - val_accuracy: 0.8463
# Epoch 41/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.0303e-09 - accuracy: 1.0000 - val_loss: 3.1015 - val_accuracy: 0.8464
# Epoch 42/50
# 782/782 [==============================] - 8s 11ms/step - loss: 7.5860e-10 - accuracy: 1.0000 - val_loss: 3.1456 - val_accuracy: 0.8463
# Epoch 43/50
# 782/782 [==============================] - 8s 11ms/step - loss: 5.6204e-10 - accuracy: 1.0000 - val_loss: 3.1868 - val_accuracy: 0.8462
# Epoch 44/50
# 782/782 [==============================] - 8s 11ms/step - loss: 4.3403e-10 - accuracy: 1.0000 - val_loss: 3.2208 - val_accuracy: 0.8464
# Epoch 45/50
# 782/782 [==============================] - 8s 10ms/step - loss: 3.3096e-10 - accuracy: 1.0000 - val_loss: 3.2591 - val_accuracy: 0.8465
# Epoch 46/50
# 782/782 [==============================] - 8s 10ms/step - loss: 2.6654e-10 - accuracy: 1.0000 - val_loss: 3.2935 - val_accuracy: 0.8467
# Epoch 47/50
# 782/782 [==============================] - 8s 11ms/step - loss: 2.1508e-10 - accuracy: 1.0000 - val_loss: 3.3264 - val_accuracy: 0.8465
# Epoch 48/50
# 782/782 [==============================] - 8s 11ms/step - loss: 1.7448e-10 - accuracy: 1.0000 - val_loss: 3.3583 - val_accuracy: 0.8463
# Epoch 49/50
# 782/782 [==============================] - 8s 10ms/step - loss: 1.4233e-10 - accuracy: 1.0000 - val_loss: 3.3907 - val_accuracy: 0.8460
# Epoch 50/50
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2034e-10 - accuracy: 1.0000 - val_loss: 3.4218 - val_accuracy: 0.8459

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
